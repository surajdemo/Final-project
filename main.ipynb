# %%
from admin import *
from user import *
a=Admin()
b=user()

while True:
    print("press 1 for admin ")
    print("press 2 for user")
    print("press 3 for exit")
    
    role=int(input("please select the role pof food orderinfg app"))
    if role==1:
        while True:
            print("press 1 for add food items")
            print("press 2 for edit food items")
            print("press 3 for view food items")
            print("press 4 for delete food items")
            print("press 5 for exit")
            
            if admin_input==1:
                a.add_food_items()
                new_item=int(input("add more items"))
                if new_item==1:
                    a.add_food_items()
            elif admin_input==2:
                a.update_food()
            elif admin_input==3:
                a.view_all_food()
            elif admin_input==4:
                a.remove_food_items()
            elif admin_input==5:
                print("exit from the application")
                break
            else:
                print("invalid input please provide valuid input")
                
    elif role==2:
        print("register your account")
        b.register()
        print("please login on to your account")
        b.login()
        while True:
            print("press 1 for place order")
            print("press 2 for show order history")
            print("press 3 for edit personal details")
            print("press 4  for exit")
            option=int(input("select your choice"))
            if option==1:
                b.place_order()

                new_item=int(input("add more items"))
                if new_item==1:
                    b.place_order()
            elif option==2:
                b.order_history()
            elif option==3:
                b.user()
            elif option==4:
                print("exit from the application")
                
        
                
    elif role==3:
        print("thanks for using our appliaction")
        break
# Out:
#   Cell In[2], line 20
#     if admin_input==1
#                      ^
# SyntaxError: expected ':'
