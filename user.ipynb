# %%
import json
import random

class user:
    def __init__(self):
        self.people={}
        self.x={}
        self.order_fooditems={}
        
        
    def register(self):
        
        self.Full_Name=input("enter the name:")
    
        self.Phone_Number=int(input("enter the mob number :"))
        
        self.Email=input("enter the email:")
        
        self.Address=input("enter the address:")
        
        self.Password=int(input("enter the passsword:"))
        
        self.item={"Unique_id":self.Unique_Id,"full_name":self.Full_Name,"phone_number":self.Phone_Number,"Email":self.Email,"address":self.Address,"password":self.Password}
        self.people[self.Email]=self.item
        with open("xyz.json","w")as f:
          json.dump(self.people,f,indent=4)
                
        return self.people
    
    def login(self):
            print("welcome to your login page")
            while True:
                email=input("enter email")
                password=input("enter the password")
                if email==self.Email & password==self.Password:
                  print("you are succesfully login")
                  break
                else:
                    print("Incorrect details please enter the correct deatails")
                    
            
    
    
    def palce_neworder(self):
        list_offood=[{"name":"Tandoori_chicken","quentity":"4 pieces","price":240},
                    {"name":"vegan-burger","quentity":"1 pieces","price":320},
                    {"name":"Truffle_cake","quentity":" 500 gram","price":900}]
        
        
        print("here is lit items")
        for i in list_offood:
            print(i)
            
            
        user_input=int(input("select the food items which you want to order"))
        if user_input==0:
            self.order_fooditems.append(list_offood)
            
        elif user_input==1:
            self.order_fooditems.append(list_offood)
            
        elif user_input==2:
            self.order_fooditems.append(list_offood)
        else:
            print("choose the items from the menue")
            
        print("press 1 for order confirmation")
        print("press 2 for order confirmation")
        option=int(input("enter your choice"))
        if option==1:
            print("order placed successfully")
        else:
            print("order canclelled")
        
        return self.order_fooditems
  


    def order_history(self):
        for i in self.order_fooditems:
            print("order history",i)
            
            
            
            
    def edit_profile(self):
        with open("personal_details.json","r")as f:
            data=json.laod(f)
            
        for k,v in data.items():
            print(f"user mail id:{k} && user deatils:{v}")
            
        mail_id=input("enter the user mail_id")
        field=input("enter the field")
        updated_value=("enter the updated value")
        data[mail_id][filed]=updated_value
        with open("personal_details.json","w")as f:
            json.dump(f)
        return data
        
  
    
                                 
        
        
        
x=user()
print(x.register())
print(x.login())
print(x.palce_neworder())
print(x.order_history())
print(x.edit_profile())
